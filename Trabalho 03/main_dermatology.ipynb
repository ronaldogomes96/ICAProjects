# %% [markdown]
# # Trabalho 3 - Base de dados dermatology

# %%
from classification_dermatology import run_perceptron_dermatology, run_mlp_simple_dermatology, run_mlp_for_chose_number_of_neurons, run_mlp_plot_score_for_epochs, run_mlp_optimized
import pandas as pd
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %% [markdown]
# # Perceptron

# %%
accuracy_train_perceptron, std_train_perceptron, accuracy_test_perceptron, std_test_perceptron = run_perceptron_dermatology()

# %% [markdown]
# # MLP

# %%
accuracy_train_mlp, std_train_mlp, accuracy_test_mlp, std_test_mlp = run_mlp_simple_dermatology()

# %% [markdown]
# ## Tabela com resultados

# %%
mean_and_std_features = {
    'Média da acuracia da fase de treinamento': [accuracy_train_perceptron * 100, accuracy_train_mlp * 100],
    'Média da acuracia da fase de testes': [accuracy_test_perceptron * 100, accuracy_test_mlp * 100],
    'Desvio padrão da fase de treino': [std_train_perceptron * 100, std_train_mlp * 100],
    'Desvio padrão da fase de testes': [std_test_perceptron * 100, std_test_mlp * 100]
}
line_names = ['Perceptron', 'MLP']
initial_results = pd.DataFrame(mean_and_std_features, index=line_names)
initial_results
# Out:
#             Média da acuracia da fase de treinamento
# Perceptron                                 98.454545  \
# MLP                                        21.951049
#
#             Média da acuracia da fase de testes
# Perceptron                            96.222222  \
# MLP                                   22.277778
#
#             Desvio padrão da fase de treino  Desvio padrão da fase de testes
# Perceptron                         1.110304                         2.134375
# MLP                                8.898252                         9.187518

# %% [markdown]
# # Escolha de neuronios da camada oculta

# %%
run_mlp_for_chose_number_of_neurons()
# Out:
# ------- VALOR MEDIO --------
# ------- RAIZ QUADRADA --------
# ------- KOMOGOROV --------
#                               Média da acuracia MLP da fase de treinamento
# Valor medio - 20 neuronios                                       99.000000  \
# Raiz quadrada - 14 neuronios                                     98.748252
# KOMOGOROV - 69 neuronios                                         99.237762
#
#                               Média da acuracia MLP da fase de testes
# Valor medio - 20 neuronios                                  97.138889  \
# Raiz quadrada - 14 neuronios                                97.472222
# KOMOGOROV - 69 neuronios                                    97.388889
#
#                               Desvio padrão da MLP fase de treino
# Valor medio - 20 neuronios                               0.425425  \
# Raiz quadrada - 14 neuronios                             0.377169
# KOMOGOROV - 69 neuronios                                 0.387402
#
#                               Desvio padrão da MLP fase de testes
# Valor medio - 20 neuronios                               1.892358
# Raiz quadrada - 14 neuronios                             1.588199
# KOMOGOROV - 69 neuronios                                 1.792474

# %% [markdown]
# # Escolha do numero de epocas

# %%
run_mlp_plot_score_for_epochs()

# %%
run_mlp_optimized()
# Out:
# (0.9789510489510489, 0.006652184050607834, 0.9625, 0.020459610920355892)
