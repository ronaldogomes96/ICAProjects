# %% [markdown]
# # Trabalho 3 -  Base de dados Coluna

# %%
from classification_spine import run_perceptron_spine, run_mlp_simple_spine, run_mlp_for_chose_number_of_neurons, run_mlp_plot_score_for_epochs, run_mlp_optimized
import pandas as pd
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %% [markdown]
# # Perceptron

# %%
accuracy_train_perceptron, std_train_perceptron, accuracy_test_perceptron, std_test_perceptron = run_perceptron_spine()

# %% [markdown]
# # MLP

# %%
accuracy_train_mlp, std_train_mlp, accuracy_test_mlp, std_test_mlp = run_mlp_simple_spine()

# %% [markdown]
# ## Tabela de resultados

# %%
mean_and_std_features = {
    'Média da acuracia da fase de treinamento': [accuracy_train_perceptron * 100, accuracy_train_mlp * 100],
    'Média da acuracia da fase de testes': [accuracy_test_perceptron * 100, accuracy_test_mlp * 100],
    'Desvio padrão da fase de treino': [std_train_perceptron * 100, std_train_mlp * 100],
    'Desvio padrão da fase de testes': [std_test_perceptron * 100, std_test_mlp * 100]
}
line_names = ['Perceptron', 'MLP']
initial_results = pd.DataFrame(mean_and_std_features, index=line_names)
initial_results
# Out:
#             Média da acuracia da fase de treinamento
# Perceptron                                 83.104839  \
# MLP                                        36.685484
#
#             Média da acuracia da fase de testes
# Perceptron                            81.161290  \
# MLP                                   37.290323
#
#             Desvio padrão da fase de treino  Desvio padrão da fase de testes
# Perceptron                         3.184463                         5.053718
# MLP                               12.515466                        13.718745

# %% [markdown]
# # Escolha de Neurônios da camada oculta

# %%
run_mlp_for_chose_number_of_neurons()
# Out:
# ------- VALOR MEDIO --------
# ------- RAIZ QUADRADA --------
# ------- KOMOGOROV --------
#                              Média da acuracia MLP da fase de treinamento
# Valor medio - 4 neuronios                                       83.193548  \
# Raiz quadrada - 4 neuronios                                     83.629032
# KOMOGOROV - 13 neuronios                                        87.274194
#
#                              Média da acuracia MLP da fase de testes
# Valor medio - 4 neuronios                                  81.387097  \
# Raiz quadrada - 4 neuronios                                81.225806
# KOMOGOROV - 13 neuronios                                   85.290323
#
#                              Desvio padrão da MLP fase de treino
# Valor medio - 4 neuronios                               2.582459  \
# Raiz quadrada - 4 neuronios                             2.317759
# KOMOGOROV - 13 neuronios                                0.974973
#
#                              Desvio padrão da MLP fase de testes
# Valor medio - 4 neuronios                               4.776046
# Raiz quadrada - 4 neuronios                             5.337321
# KOMOGOROV - 13 neuronios                                4.287290

# %% [markdown]
# # Escolha do número de épocas

# %%
run_mlp_plot_score_for_epochs()

# %%
run_mlp_optimized()
# Out:
# (0.8743548387096775,
#  0.011038670085334618,
#  0.8616129032258064,
#  0.03898957943977774)
