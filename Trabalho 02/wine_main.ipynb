# %%
from classification_tests_wine import test_knn_wine, test_dmc_wine
import pandas as pd
import numpy as np

# %% [markdown]
# # Trabalho 2 - Reconhecimento de Padrões - Base de dados Wine
#
# Os dados foram distribuidos em 90% para treino e 10% para teste. São feitas 50 rodadas de treino e teste, cada uma com dados embaralhados e aleatorios em comparação com o anterior
#
# ## Nearest Neighbor - NN
#
# obs: Este classificador é equivalente ao modelo k Nearest Neighbors - kNN, porém com 1 vizinho

# %%
knn_one_neighbor = test_knn_wine(1)
# Out:
# ---------- KNN for Wine with 1 neighbor ------------------
#
#
#
# Epoch 1
#
# Confusion matrix
# Acurracy: 77.77777777777779 %
#
#
# Epoch 2
#
# Confusion matrix
# Acurracy: 55.55555555555556 %
#
#
# Epoch 3
#
# Confusion matrix
# Acurracy: 66.66666666666666 %
#
#
# Epoch 4
#
# Confusion matrix
# Acurracy: 77.77777777777779 %
#
#
# Epoch 5
#
# Confusion matrix
# Acurracy: 72.22222222222221 %
#
#
# Epoch 6
#
# Confusion matrix
# Acurracy: 83.33333333333334 %
#
#
# Epoch 7
#
# Confusion matrix
# Acurracy: 83.33333333333334 %
#
#
# Epoch 8
#
# Confusion matrix
# Acurracy: 94.44444444444444 %
#
#
# Epoch 9
#
# Confusion matrix
# Acurracy: 55.55555555555556 %
#
#
# Epoch 10
#
# Confusion matrix
# Acurracy: 83.33333333333334 %
#
#
# Epoch 11
#
# Confusion matrix
# Acurracy: 61.111111111111114 %
#
#
# Epoch 12
#
# Confusion matrix
# Acurracy: 77.77777777777779 %
#
#
# Epoch 13
#
# Confusion matrix
# Acurracy: 72.22222222222221 %
#
#
# Epoch 14
#
# Confusion matrix
# ...

# %% [markdown]
# ##  k Nearest Neighbors - KNN
#
# ### K = 3

# %%
knn_three_neighbor = test_knn_wine(3)
# Out:
# ---------- KNN for Wine with 3 neighbor ------------------
#
#
#
# Epoch 1
#
# Confusion matrix
# Acurracy: 61.111111111111114 %
#
#
# Epoch 2
#
# Confusion matrix
# Acurracy: 83.33333333333334 %
#
#
# Epoch 3
#
# Confusion matrix
# Acurracy: 50.0 %
#
#
# Epoch 4
#
# Confusion matrix
# Acurracy: 50.0 %
#
#
# Epoch 5
#
# Confusion matrix
# Acurracy: 83.33333333333334 %
#
#
# Epoch 6
#
# Confusion matrix
# Acurracy: 61.111111111111114 %
#
#
# Epoch 7
#
# Confusion matrix
# Acurracy: 83.33333333333334 %
#
#
# Epoch 8
#
# Confusion matrix
# Acurracy: 55.55555555555556 %
#
#
# Epoch 9
#
# Confusion matrix
# Acurracy: 55.55555555555556 %
#
#
# Epoch 10
#
# Confusion matrix
# Acurracy: 72.22222222222221 %
#
#
# Epoch 11
#
# Confusion matrix
# Acurracy: 83.33333333333334 %
#
#
# Epoch 12
#
# Confusion matrix
# Acurracy: 83.33333333333334 %
#
#
# Epoch 13
#
# Confusion matrix
# Acurracy: 66.66666666666666 %
#
#
# Epoch 14
#
# Confusion matrix
# Acurracy: 77.77777777777779 %
#
#
# Epoch 15
#
# ...

# %% [markdown]
# ### K = 5

# %%
knn_five_neighbor = test_knn_wine(5)
# Out:
# ---------- KNN for Wine with 5 neighbor ------------------
#
#
#
# Epoch 1
#
# Confusion matrix
# Acurracy: 61.111111111111114 %
#
#
# Epoch 2
#
# Confusion matrix
# Acurracy: 61.111111111111114 %
#
#
# Epoch 3
#
# Confusion matrix
# Acurracy: 77.77777777777779 %
#
#
# Epoch 4
#
# Confusion matrix
# Acurracy: 61.111111111111114 %
#
#
# Epoch 5
#
# Confusion matrix
# Acurracy: 66.66666666666666 %
#
#
# Epoch 6
#
# Confusion matrix
# Acurracy: 88.88888888888889 %
#
#
# Epoch 7
#
# Confusion matrix
# Acurracy: 66.66666666666666 %
#
#
# Epoch 8
#
# Confusion matrix
# Acurracy: 83.33333333333334 %
#
#
# Epoch 9
#
# Confusion matrix
# Acurracy: 55.55555555555556 %
#
#
# Epoch 10
#
# Confusion matrix
# Acurracy: 77.77777777777779 %
#
#
# Epoch 11
#
# Confusion matrix
# Acurracy: 88.88888888888889 %
#
#
# Epoch 12
#
# Confusion matrix
# Acurracy: 77.77777777777779 %
#
#
# Epoch 13
#
# Confusion matrix
# Acurracy: 61.111111111111114 %
#
#
# Epoch 14
#
# Confusion matrix
# ...

# %% [markdown]
# ### K = 7

# %%
knn_seven_neighbor = test_knn_wine(7)
# Out:
# ---------- KNN for Wine with 7 neighbor ------------------
#
#
#
# Epoch 1
#
# Confusion matrix
# Acurracy: 77.77777777777779 %
#
#
# Epoch 2
#
# Confusion matrix
# Acurracy: 66.66666666666666 %
#
#
# Epoch 3
#
# Confusion matrix
# Acurracy: 72.22222222222221 %
#
#
# Epoch 4
#
# Confusion matrix
# Acurracy: 72.22222222222221 %
#
#
# Epoch 5
#
# Confusion matrix
# Acurracy: 61.111111111111114 %
#
#
# Epoch 6
#
# Confusion matrix
# Acurracy: 38.88888888888889 %
#
#
# Epoch 7
#
# Confusion matrix
# Acurracy: 66.66666666666666 %
#
#
# Epoch 8
#
# Confusion matrix
# Acurracy: 72.22222222222221 %
#
#
# Epoch 9
#
# Confusion matrix
# Acurracy: 77.77777777777779 %
#
#
# Epoch 10
#
# Confusion matrix
# Acurracy: 72.22222222222221 %
#
#
# Epoch 11
#
# Confusion matrix
# Acurracy: 77.77777777777779 %
#
#
# Epoch 12
#
# Confusion matrix
# Acurracy: 50.0 %
#
#
# Epoch 13
#
# Confusion matrix
# Acurracy: 66.66666666666666 %
#
#
# Epoch 14
#
# Confusion matrix
# Acurracy: 61.111111111111114 %
#
#
# ...

# %% [markdown]
# ## DMC - Distância média dos centroides

# %%
dmc = test_dmc_wine()
# Out:
# ---------- DMC for Wine ------------------
#
#
#
# Epoch 1
#
# Confusion matrix
# Acurracy: 83.33333333333334 %
#
#
# Epoch 2
#
# Confusion matrix
# Acurracy: 72.22222222222221 %
#
#
# Epoch 3
#
# Confusion matrix
# Acurracy: 61.111111111111114 %
#
#
# Epoch 4
#
# Confusion matrix
# Acurracy: 72.22222222222221 %
#
#
# Epoch 5
#
# Confusion matrix
# Acurracy: 83.33333333333334 %
#
#
# Epoch 6
#
# Confusion matrix
# Acurracy: 61.111111111111114 %
#
#
# Epoch 7
#
# Confusion matrix
# Acurracy: 72.22222222222221 %
#
#
# Epoch 8
#
# Confusion matrix
# Acurracy: 66.66666666666666 %
#
#
# Epoch 9
#
# Confusion matrix
# Acurracy: 88.88888888888889 %
#
#
# Epoch 10
#
# Confusion matrix
# Acurracy: 83.33333333333334 %
#
#
# Epoch 11
#
# Confusion matrix
# Acurracy: 88.88888888888889 %
#
#
# Epoch 12
#
# Confusion matrix
# Acurracy: 72.22222222222221 %
#
#
# Epoch 13
#
# Confusion matrix
# Acurracy: 88.88888888888889 %
#
#
# Epoch 14
#
# Confusion matrix
# Acurracy: 88.88888888888889 %
#
#
# ...

# %% [markdown]
# # Coletando resultados
#
# A seguir temos a tabela com média e desvio padrão das taxas de acerto de cada classificador

# %%
mean_and_std_all_features = {
    'Média com todas as features': [np.mean(knn_one_neighbor), np.mean(knn_three_neighbor), np.mean(knn_five_neighbor), np.mean(knn_seven_neighbor), np.mean(dmc)],
    'Desvio Padrão com todas as features': [np.std(knn_one_neighbor), np.std(knn_three_neighbor), np.std(knn_five_neighbor), np.std(knn_seven_neighbor), np.std(dmc)]
}
line_names = ['KNN - K=1', 'KNN - K=3', 'KNN - K=5', 'KNN - K=7', 'DMC']
result_with_all_features = pd.DataFrame(mean_and_std_all_features, index=line_names)
result_with_all_features
# Out:
#            Média com todas as features  Desvio Padrão com todas as features
# KNN - K=1                     0.744444                             0.111665
# KNN - K=3                     0.710000                             0.109031
# KNN - K=5                     0.708889                             0.097221
# KNN - K=7                     0.676667                             0.102854
# DMC                           0.735556                             0.113072
