# %% [markdown]
# # Trabalho 4 - Base de dados Torneamento

# %%
from classification_torneamento import run_mlp_for_chose_number_of_neurons, run_mlp_plot_score_for_epochs, run_mlp_torneamento
import pandas as pd
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %% [markdown]
# # MLP
#
# ### Escolha do numero de neuronios

# %%
run_mlp_for_chose_number_of_neurons()
# Out:
#                              Média da acuracia MLP da fase de treinamento
# Valor medio - 7 neuronios                                          40.725  \
# Raiz quadrada - 6 neuronios                                        39.925
# KOMOGOROV - 19 neuronios                                           45.675
#
#                              Média da acuracia MLP da fase de testes
# Valor medio - 7 neuronios                                  33.000000  \
# Raiz quadrada - 6 neuronios                                33.333333
# KOMOGOROV - 19 neuronios                                   37.500000
#
#                              Desvio padrão da MLP fase de treino
# Valor medio - 7 neuronios                               2.844109  \
# Raiz quadrada - 6 neuronios                             3.236822
# KOMOGOROV - 19 neuronios                                2.789975
#
#                              Desvio padrão da MLP fase de testes
# ...

# %% [markdown]
# ### Escolha do numero de epocas

# %%
run_mlp_plot_score_for_epochs()

# %% [markdown]
# ### MLP otimizada com resultados finais

# %%
mlp_accuracy_mean_train, mlp_std_train, mlp_accuracy_mean_test, mlp_std_test = run_mlp_torneamento()
mlp_accuracy_mean_train, mlp_std_train, mlp_accuracy_mean_test, mlp_std_test
# Out:
# (0.8697499999999999,
#  0.019752109591973547,
#  0.7666666666666666,
#  0.049216076867444676)
